# %%
from sympy import symbols, diff, tan, asinh, cos, sqrt, hessian, atanh

# Define the variable
s = symbols("s", real=True)

# Define the function
# f = s * tan(s) * asinh(s) - s**1.3 * cos(s) + sqrt(s)
f = (
    s
    * tan(s)
    * asinh(s)
    * atanh(s)
    * s  # .tan().mul(&s.asinh().mul(&s.atanh())).mul(&s)
    - s**1.3 * cos(s)  # .sub(&s.powf(1.3).mul(&s.cos()))
    + sqrt(s)  # .add(&s.sqrt())
    - (s / 1.441 + 1 / s)  # .sub(&s.div_value(1.441).add(&s.recip()))
    - (-6.235 / s)  # .sub(&(-125.235).div_var(&s))
)

# Compute the derivative with respect to s
df = diff(f, s)
ddf = diff(diff(f, s))

# Display the result
from symars import DType, GenScalar
from symars.scalar_cached import GenScalarCached

# gen = GenScalar(DType.F64)
gen = GenScalarCached(DType.F64)
gcode = gen.generate("grad_2", df)
print(gcode)

hcode = gen.generate("hess_2", expr=ddf)
# print(hcode)

# %%
from sympy import (
    symbols,
    diff,
    tan,
    asinh,
    cos,
    sqrt,
    hessian,
    atanh,
    acosh,
    sinh,
    Abs,
    cosh,
    acos,
)
import sympy as sp

# Define the variable
s = symbols("s", positive=True)

f = (
    s * tan(s) * asinh(s) ** 2 * s  # .tan().mul(&s.asinh().square()).mul(&s)
    - s**1.3 * cos(s)  # .sub(&s.powf(1.3).mul(&s.cos()))
    + sqrt(s)  # .add(&s.sqrt())
    - (s / 1.441 + 1 / s)  # .sub(&s.div_value(1.441).add(&s.recip()))
    - (-6.235 / s + sinh(s**3))  # .sub(&(-6.235).div_var(&s).add(&s.powi(3).sinh()))
    + (
        s ** (-1.24) / abs(s / 12.4)
    )  # .add(&(s.powf(-1.24).div(&s.div_value(12.4).abs())))
)

f = Abs(f)

# Compute the derivative with respect to s
df = diff(f, s)
ddf = diff(diff(f, s))

# Display the result
from symars import DType, GenScalar
from symars.scalar_cached import GenScalarCached

# gen = GenScalar(DType.F64)
gen = GenScalarCached(DType.F64)
gcode = gen.generate("grad_3", df)
print(gcode)

hcode = gen.generate("hess_3", expr=ddf)
# print(hcode)
# Out:
# /*
#
# * Code generated by Symars. Thank you for using Symars!
#   Symars is licensed under MIT licnese.
#   Repository: https://github.com/Da1sypetals/Symars
#
# * Computation code is not intended for manual editing.
#
# * If you find an error,
#   or if you believe Symars generates incorrect result,
#   please raise an issue under our repo with minimal reproducible example.
#
# */
#
#
#
# #[inline]
# pub  fn grad_3(s: f64) -> f64 {
#
#     let __intermediate_result_9 = (s).powf(1.30000000000000_f64);
# let __intermediate_result_12 = (s).powi(2);
# let __intermediate_result_14 = (s).powi(3);
# let __intermediate_result_17 = (s).cos();
# let __intermediate_result_19 = ((s).asinh()).powi(2);
# let __intermediate_result_23 = (s).tan();
#
#     ((((-0.693962526023595_f64) + (((0.50000000000000000000_f64) * ((s).powf(-0.50000000000000000000_f64)))) + (((-27.7760000000000_f64) * ((s).powf(-3.24000000000000_f64)))) + (((-5.23500000000000_f64) * ((s).powi(-2)))) + ((((__intermediate_result_9)) * ((s).sin()))) + (((-3.0000000000000000000_f64) * ((__intermediate_result_12)) * (((__intermediate_result_14)).cosh()))) + (((-1.30000000000000_f64) * ((s).powf(0.300000000000000_f64)) * ((__intermediate_result_17)))) + ((((__intermediate_result_12)) * ((__intermediate_result_19)) * (((1.0000000000000000000_f64) + (((__intermediate_result_23)).powi(2)))))) + (((2.0000000000000000000_f64) * (s) * ((__intermediate_result_19)) * ((__intermediate_result_23)))) + (((2.0000000000000000000_f64) * ((__intermediate_result_12)) * ((((1.0000000000000000000_f64) + ((__intermediate_result_12)))).powf(-0.50000000000000000000_f64)) * ((s).asinh()) * ((__intermediate_result_23)))))) * (((((s).sqrt()) + ((-(((__intermediate_result_14)).sinh()))) + (((5.23500000000000_f64) * ((s).recip()))) + (((12.4000000000000_f64) * ((s).powf(-2.24000000000000_f64)))) + (((-0.693962526023595_f64) * (s))) + ((-((((__intermediate_result_9)) * ((__intermediate_result_17)))))) + ((((__intermediate_result_12)) * ((__intermediate_result_19)) * ((__intermediate_result_23)))))).sinh()))
#
# }
